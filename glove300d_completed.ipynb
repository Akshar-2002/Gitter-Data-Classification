# %%
import logging
import pandas as pd
import numpy as np
import gensim
import nltk
import re
from bs4 import BeautifulSoup
import csv
import warnings
warnings.filterwarnings ('ignore')

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS =nltk.corpus.stopwords.words('english')

def clean_text(text):
    if type(text)==str:
        
        text = BeautifulSoup(text, "lxml").text # HTML decoding
        text = text.lower() # lowercase text
        text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
        text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
        text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
        return text
    return ""

# %%
wv = pd.read_table('glove.6B.300d.txt', sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)

# %%
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='english'):
        for word in nltk.word_tokenize(sent, language='english'):
            if len(word) < 2:
                continue
            tokens.append(word)
    return tokens

# %%
def wordprint(words,wv):
    all_words, mean = set(), []
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.index:
            a=np.array(wv.loc[word].to_numpy())
            mean.append(a)
    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        # FIXME: remove these examples in pre-processing
        return np.zeros(300,)   
    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

# %%
def  word_averaging_listn(wv, text_list):
    return np.vstack([wordprint(post,wv) for post in text_list ])

# %%
fname='GitterCom'+'.csv'
df = pd.read_csv(fname,encoding='utf8')
df['message'] = df['message'].apply(clean_text)
df.drop(['Channel','messageId','time','user'],axis=1,inplace=True)
df['Category']=df['Category'].str.lower()
df['Purpose']=df['Purpose'].str.lower()
df['Subcategory']=df['Subcategory'].str.lower()
print(df.head(10))
comtdata=df
test_tokenized = comtdata.apply(lambda r: w2v_tokenize_text(r['message']), axis=1).values
X_comtdata_averagen=word_averaging_listn(wv, test_tokenized)
fname='completed_glove300d'+'.csv'
np.savetxt(fname,X_comtdata_averagen, delimiter=',', fmt='%f')
df = pd.read_csv('GitterCom.csv',encoding='utf8')
df['message'] = df['message'].apply(clean_text)
print(df.head(10))
comtdata=df

test_tokenized = comtdata.apply(lambda r: w2v_tokenize_text(r['message']), axis=1).values


X_comtdata_averagen=word_averaging_listn(wv, test_tokenized)

np.savetxt('glove300d.csv',X_comtdata_averagen, delimiter=',', fmt='%f')
# Out:
#                                              message    Purpose  \
# 0  hi team recently upgraded cucumberjvm version ...  team wide
# 1  exception thread main javalangnosuchmethoderro...  team wide
# 2  amit007 looks like inconsistent cucumber jar v...  team wide
# 3                        github trying replace irc p  team wide
# 4  aslakhellesoy thanks seems like using older ve...  team wide
# 5  hi one question friends starting project studi...  team wide
# 6  danon9111 integrate cucumber another testing f...  team wide
# 7  aslakhellesoy reading cucumber book found code...  team wide
# 8                 sidkiyassine call methods directly  team wide
# 9  intergrated cucumber+appium https githubcom pr...  team wide
#
#         Category                          Subcategory
# 0        dev-ops  development operation notifications
# 1        dev-ops  development operation notifications
# 2  communication         communication with teammates
# 3  communication         communication with teammates
# 4  communication         communication with teammates
# 5        dev-ops                             team q&a
# 6        dev-ops                             team q&a
# 7        dev-ops                             team q&a
# 8        dev-ops                             team q&a
# 9        dev-ops  development operation notifications
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cucumberjvm', 'threadsafe']
# WARNING:root:cannot compute similarity with no input ['gherkin3']
# WARNING:root:cannot compute similarity with no input ['gherkin3']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nthank', 'younnn']
# WARNING:root:cannot compute similarity with no input ['ntttinfocukesntttcucumberjavanttt122nttttestnttttnttntttinfocukesntttcucumberjunitnttt122nttttestnttnttntttjunitntttjunitnttt412nttttestnttnttntt', 'orgseleniumhqseleniumntt', 'seleniumjavantt', '2482ntt']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['woondering']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['featurelogin']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['javalangnullpointerexceptionntat', 'netmasterthoughtcucumberutilutiltovalidfilename', 'utiljava50', 'ntat', 'netmasterthoughtcucumberjsonfeaturecalculatereportfilename', 'featurejava179', 'ntat', 'netmasterthoughtcucumberjsonfeaturesetmetadata', 'featurejava159', 'ntat', 'netmasterthoughtcucumberreportparsersetmetadata', 'reportparserjava91', 'ntat', 'netmasterthoughtcucumberreportparserparsejsonresults', 'reportparserjava61', 'ntat', 'netmasterthoughtcucumberreportbuildergeneratereports', 'reportbuilderjava56', 'ntat', 'netmasterthoughtjenkinscucumberreportpublishergeneratereport', 'cucumberreportpublisherjava125', 'ntat', 'netmasterthoughtjenkinscucumberreportpublisherperform', 'cucumberreportpublisherjava70', 'ntat', 'hudsontasksbuildstepcompatibilitylayerperform', 'buildstepcompatibilitylayerjava78', 'ntat', 'hudsontasksbuildstepmonitor1perform', 'buildstepmonitorjava20']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['worknlike']
# WARNING:root:cannot compute similarity with no input ['worknnlike']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ctrueden']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['inputdatagerimgplus']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['createnewwindow', 'shouldnt']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ctrueden']
# WARNING:root:cannot compute similarity with no input ['ctrueden', 'wiscedu']
# WARNING:root:cannot compute similarity with no input ['knimeimagejnet']
# WARNING:root:cannot compute similarity with no input ['ctrueden']
# WARNING:root:cannot compute similarity with no input ['meee', 'tooooooo']
# WARNING:root:cannot compute similarity with no input ['jhipster']
# WARNING:root:cannot compute similarity with no input ['gradle']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['indexhtml']
# WARNING:root:cannot compute similarity with no input ['duuuude']
# WARNING:root:cannot compute similarity with no input ['mvn', 'pprod', 'springbootrun']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['shouldnt']
# WARNING:root:cannot compute similarity with no input ['deepu105', 'nhttps', 'gistgithubcom', 'iuricmp', 'bb7f96a8ae6e6678cd75nhttps', 'gistgithubcom', 'iuricmp', '160dd880fb72262ca663']
# WARNING:root:cannot compute similarity with no input ['ngflow']
# WARNING:root:cannot compute similarity with no input ['orgmapstructapmappingprocessor']
# WARNING:root:cannot compute similarity with no input ['utc0600']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nvm']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['understandu2026trust']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['egnhtmlnnnn']
# WARNING:root:cannot compute similarity with no input ['buildsfx']
# WARNING:root:cannot compute similarity with no input ['jspmmap']
# WARNING:root:cannot compute similarity with no input ['robwormald']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['bundlemodulesjs']
# WARNING:root:cannot compute similarity with no input ['configjs']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['jspm', 'autodetect']
# WARNING:root:cannot compute similarity with no input ['__origin__']
# WARNING:root:cannot compute similarity with no input ['cobbweb']
# WARNING:root:cannot compute similarity with no input ['jmeas']
# WARNING:root:cannot compute similarity with no input ['u2026so']
# WARNING:root:cannot compute similarity with no input ['magnent']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['changelog']
# WARNING:root:cannot compute similarity with no input ['cooool']
# WARNING:root:cannot compute similarity with no input ['behaviorkey']
# WARNING:root:cannot compute similarity with no input ['eventkey']
# WARNING:root:cannot compute similarity with no input ['behaviorcompileevents']
# WARNING:root:cannot compute similarity with no input ['_object']
# WARNING:root:cannot compute similarity with no input ['editsx']
# WARNING:root:cannot compute similarity with no input ['downvote']
# WARNING:root:cannot compute similarity with no input ['hahaha']
# WARNING:root:cannot compute similarity with no input ['thatu2019s', 'samccone']
# WARNING:root:cannot compute similarity with no input ['edittooquickly']
# WARNING:root:cannot compute similarity with no input ['jmeaspls']
# WARNING:root:cannot compute similarity with no input ['ocky', 'doesnu2019t', 'initializers', 'finalizers']
# WARNING:root:cannot compute similarity with no input ['jmeas']
# WARNING:root:cannot compute similarity with no input ['rebase']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cobbweb']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['editsfetch']
# WARNING:root:cannot compute similarity with no input ['ie8+']
# WARNING:root:cannot compute similarity with no input ['hardlinks']
# WARNING:root:cannot compute similarity with no input ['uiidontexist']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['200dev']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['tojson']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['jmeas', 'upvotez']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['v22']
# WARNING:root:cannot compute similarity with no input ['_bind', 'globalchreqresrequest', 'globalchreqres']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['jasonlaster']
# WARNING:root:cannot compute similarity with no input ['mbpr']
# WARNING:root:cannot compute similarity with no input ['samccone']
# WARNING:root:cannot compute similarity with no input ['amurica']
# WARNING:root:cannot compute similarity with no input ['u2018murica']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nonmurican']
# WARNING:root:cannot compute similarity with no input ['marionettecallbacksreset']
# WARNING:root:cannot compute similarity with no input ['startwithparent']
# WARNING:root:cannot compute similarity with no input ['initilizers']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cobbweb']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['dlmachine']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['4274']
# WARNING:root:cannot compute similarity with no input ['amueller', 'wdyt']
# WARNING:root:cannot compute similarity with no input ['4318']
# WARNING:root:cannot compute similarity with no input ['train_idx', 'validation_idx', 'train_test_split', 'nparange', 'n_samples', 'test_size02', 'random_state0']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['pipinstalled']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['npunique', 'clusteringlabels_']
# WARNING:root:cannot compute similarity with no input ['function__file__']
# WARNING:root:cannot compute similarity with no input ['func__code__']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['symregressor']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ossrh_username']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['21612764883168']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['socketwriter']
# WARNING:root:cannot compute similarity with no input ['ts3api', 'ts3apiasync']
# WARNING:root:cannot compute similarity with no input ['rigth', 'facepalm']
# WARNING:root:cannot compute similarity with no input ['ts3']
# WARNING:root:cannot compute similarity with no input ['schedulerruntaslatfixedrate']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ntnttcatalogntntnttsidebarntnn']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['uikitif']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['kerbymart', 'classukwidth11', 'ukwidthmedium12']
# WARNING:root:cannot compute similarity with no input ['j33']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['hrefjpg', 'hrefpng', 'hrefgif', 'attr', 'datauklightbox', 'groupgallery', 'u201c']
# WARNING:root:cannot compute similarity with no input ['tttttttttntttttttttttitle', 'nttttttttttnttttttttt']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ukfloatleft', 'ukwidthsmall11']
# WARNING:root:cannot compute similarity with no input ['alignleft']
# WARNING:root:cannot compute similarity with no input ['malles', 'ukmarginbottomremove']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['widgetkit']
# WARNING:root:cannot compute similarity with no input ['uikit']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['aheinze', 'usefull']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['florianletsch', 'typoed']
# WARNING:root:cannot compute similarity with no input ['thisitemproductid']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['skullbockn']
# WARNING:root:cannot compute similarity with no input ['thumbsup']
# WARNING:root:cannot compute similarity with no input ['hlsl']
# WARNING:root:cannot compute similarity with no input ['probaby', 'xenko']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['imgui', 'nuklear']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['libcoredll']
# WARNING:root:cannot compute similarity with no input ['necesserly']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['xen2', 'kryptosfr']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ahahahahaha']
# WARNING:root:cannot compute similarity with no input ['ahah']
#     Channel                 messageId                      time  \
# 0  Cucumber  5551fd48f853e7f14c2b7b3c  2015-05-12T13:16:56.794Z
# 1  Cucumber  5551fd4a00ed57993752bbb5  2015-05-12T13:16:58.574Z
# 2  Cucumber  5551feedf853e7f14c2b7b62  2015-05-12T13:23:57.768Z
# 3  Cucumber  5552032a1817239c37e4e01b  2015-05-12T13:42:02.416Z
# 4  Cucumber  55520e5900ed57993752be4e  2015-05-12T14:29:45.058Z
# 5  Cucumber  55637ddfbd9b9407519bef4b  2015-05-25T19:54:07.526Z
# 6  Cucumber  55649744220dcade3c4d5503  2015-05-26T15:54:44.800Z
# 7  Cucumber  556498018f5532b4396ac6d1  2015-05-26T15:57:53.346Z
# 8  Cucumber  5565704b8f5532b4396adb01  2015-05-27T07:20:43.093Z
# 9  Cucumber  5565d8a31d1bf91146cb914f  2015-05-27T14:45:55.343Z
#
#              user                                            message  \
# 0         amit007  hi team recently upgraded cucumberjvm version ...
# 1         amit007  exception thread main javalangnosuchmethoderro...
# 2   aslakhellesoy  amit007 looks like inconsistent cucumber jar v...
# 3          LiohAu                        github trying replace irc p
# 4         amit007  aslakhellesoy thanks seems like using older ve...
# 5       Danon9111  hi one question friends starting project studi...
# 6        DEllster  danon9111 integrate cucumber another testing f...
# 7        DEllster  aslakhellesoy reading cucumber book found code...
# 8   aslakhellesoy                 sidkiyassine call methods directly
# 9  priyankshah217  intergrated cucumber+appium https githubcom pr...
#
#      Purpose       Category                          Subcategory
# 0  Team Wide        Dev-Ops  Development Operation Notifications
# 1  Team Wide        Dev-Ops  Development Operation Notifications
# 2  Team Wide  Communication         Communication with Teammates
# 3  Team Wide  Communication         Communication with Teammates
# 4  Team Wide  Communication         Communication with Teammates
# 5  Team Wide        Dev-Ops                             Team Q&A
# 6  Team Wide        Dev-Ops                             Team Q&A
# 7  Team Wide        Dev-Ops                             Team Q&A
# 8  Team Wide        Dev-Ops                             Team Q&A
# 9  Team Wide        Dev-Ops  Development Operation Notifications
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cucumberjvm', 'threadsafe']
# WARNING:root:cannot compute similarity with no input ['gherkin3']
# WARNING:root:cannot compute similarity with no input ['gherkin3']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nthank', 'younnn']
# WARNING:root:cannot compute similarity with no input ['ntttinfocukesntttcucumberjavanttt122nttttestnttttnttntttinfocukesntttcucumberjunitnttt122nttttestnttnttntttjunitntttjunitnttt412nttttestnttnttntt', 'orgseleniumhqseleniumntt', 'seleniumjavantt', '2482ntt']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['woondering']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['featurelogin']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['javalangnullpointerexceptionntat', 'netmasterthoughtcucumberutilutiltovalidfilename', 'utiljava50', 'ntat', 'netmasterthoughtcucumberjsonfeaturecalculatereportfilename', 'featurejava179', 'ntat', 'netmasterthoughtcucumberjsonfeaturesetmetadata', 'featurejava159', 'ntat', 'netmasterthoughtcucumberreportparsersetmetadata', 'reportparserjava91', 'ntat', 'netmasterthoughtcucumberreportparserparsejsonresults', 'reportparserjava61', 'ntat', 'netmasterthoughtcucumberreportbuildergeneratereports', 'reportbuilderjava56', 'ntat', 'netmasterthoughtjenkinscucumberreportpublishergeneratereport', 'cucumberreportpublisherjava125', 'ntat', 'netmasterthoughtjenkinscucumberreportpublisherperform', 'cucumberreportpublisherjava70', 'ntat', 'hudsontasksbuildstepcompatibilitylayerperform', 'buildstepcompatibilitylayerjava78', 'ntat', 'hudsontasksbuildstepmonitor1perform', 'buildstepmonitorjava20']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['worknlike']
# WARNING:root:cannot compute similarity with no input ['worknnlike']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ctrueden']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['inputdatagerimgplus']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['createnewwindow', 'shouldnt']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ctrueden']
# WARNING:root:cannot compute similarity with no input ['ctrueden', 'wiscedu']
# WARNING:root:cannot compute similarity with no input ['knimeimagejnet']
# WARNING:root:cannot compute similarity with no input ['ctrueden']
# WARNING:root:cannot compute similarity with no input ['meee', 'tooooooo']
# WARNING:root:cannot compute similarity with no input ['jhipster']
# WARNING:root:cannot compute similarity with no input ['gradle']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['indexhtml']
# WARNING:root:cannot compute similarity with no input ['duuuude']
# WARNING:root:cannot compute similarity with no input ['mvn', 'pprod', 'springbootrun']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['shouldnt']
# WARNING:root:cannot compute similarity with no input ['deepu105', 'nhttps', 'gistgithubcom', 'iuricmp', 'bb7f96a8ae6e6678cd75nhttps', 'gistgithubcom', 'iuricmp', '160dd880fb72262ca663']
# WARNING:root:cannot compute similarity with no input ['ngflow']
# WARNING:root:cannot compute similarity with no input ['orgmapstructapmappingprocessor']
# WARNING:root:cannot compute similarity with no input ['utc0600']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nvm']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['understandu2026trust']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['egnhtmlnnnn']
# WARNING:root:cannot compute similarity with no input ['buildsfx']
# WARNING:root:cannot compute similarity with no input ['jspmmap']
# WARNING:root:cannot compute similarity with no input ['robwormald']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['bundlemodulesjs']
# WARNING:root:cannot compute similarity with no input ['configjs']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['jspm', 'autodetect']
# WARNING:root:cannot compute similarity with no input ['__origin__']
# WARNING:root:cannot compute similarity with no input ['cobbweb']
# WARNING:root:cannot compute similarity with no input ['jmeas']
# WARNING:root:cannot compute similarity with no input ['u2026so']
# WARNING:root:cannot compute similarity with no input ['magnent']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['changelog']
# WARNING:root:cannot compute similarity with no input ['cooool']
# WARNING:root:cannot compute similarity with no input ['behaviorkey']
# WARNING:root:cannot compute similarity with no input ['eventkey']
# WARNING:root:cannot compute similarity with no input ['behaviorcompileevents']
# WARNING:root:cannot compute similarity with no input ['_object']
# WARNING:root:cannot compute similarity with no input ['editsx']
# WARNING:root:cannot compute similarity with no input ['downvote']
# WARNING:root:cannot compute similarity with no input ['hahaha']
# WARNING:root:cannot compute similarity with no input ['thatu2019s', 'samccone']
# WARNING:root:cannot compute similarity with no input ['edittooquickly']
# WARNING:root:cannot compute similarity with no input ['jmeaspls']
# WARNING:root:cannot compute similarity with no input ['ocky', 'doesnu2019t', 'initializers', 'finalizers']
# WARNING:root:cannot compute similarity with no input ['jmeas']
# WARNING:root:cannot compute similarity with no input ['rebase']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cobbweb']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['editsfetch']
# WARNING:root:cannot compute similarity with no input ['ie8+']
# WARNING:root:cannot compute similarity with no input ['hardlinks']
# WARNING:root:cannot compute similarity with no input ['uiidontexist']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['200dev']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['tojson']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['jmeas', 'upvotez']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['v22']
# WARNING:root:cannot compute similarity with no input ['_bind', 'globalchreqresrequest', 'globalchreqres']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['jasonlaster']
# WARNING:root:cannot compute similarity with no input ['mbpr']
# WARNING:root:cannot compute similarity with no input ['samccone']
# WARNING:root:cannot compute similarity with no input ['amurica']
# WARNING:root:cannot compute similarity with no input ['u2018murica']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nonmurican']
# WARNING:root:cannot compute similarity with no input ['marionettecallbacksreset']
# WARNING:root:cannot compute similarity with no input ['startwithparent']
# WARNING:root:cannot compute similarity with no input ['initilizers']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cobbweb']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['dlmachine']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['4274']
# WARNING:root:cannot compute similarity with no input ['amueller', 'wdyt']
# WARNING:root:cannot compute similarity with no input ['4318']
# WARNING:root:cannot compute similarity with no input ['train_idx', 'validation_idx', 'train_test_split', 'nparange', 'n_samples', 'test_size02', 'random_state0']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['pipinstalled']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['npunique', 'clusteringlabels_']
# WARNING:root:cannot compute similarity with no input ['function__file__']
# WARNING:root:cannot compute similarity with no input ['func__code__']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['symregressor']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ossrh_username']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['21612764883168']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['socketwriter']
# WARNING:root:cannot compute similarity with no input ['ts3api', 'ts3apiasync']
# WARNING:root:cannot compute similarity with no input ['rigth', 'facepalm']
# WARNING:root:cannot compute similarity with no input ['ts3']
# WARNING:root:cannot compute similarity with no input ['schedulerruntaslatfixedrate']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ntnttcatalogntntnttsidebarntnn']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['uikitif']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['kerbymart', 'classukwidth11', 'ukwidthmedium12']
# WARNING:root:cannot compute similarity with no input ['j33']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['hrefjpg', 'hrefpng', 'hrefgif', 'attr', 'datauklightbox', 'groupgallery', 'u201c']
# WARNING:root:cannot compute similarity with no input ['tttttttttntttttttttttitle', 'nttttttttttnttttttttt']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ukfloatleft', 'ukwidthsmall11']
# WARNING:root:cannot compute similarity with no input ['alignleft']
# WARNING:root:cannot compute similarity with no input ['malles', 'ukmarginbottomremove']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['widgetkit']
# WARNING:root:cannot compute similarity with no input ['uikit']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['aheinze', 'usefull']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['florianletsch', 'typoed']
# WARNING:root:cannot compute similarity with no input ['thisitemproductid']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['skullbockn']
# WARNING:root:cannot compute similarity with no input ['thumbsup']
# WARNING:root:cannot compute similarity with no input ['hlsl']
# WARNING:root:cannot compute similarity with no input ['probaby', 'xenko']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['imgui', 'nuklear']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['libcoredll']
# WARNING:root:cannot compute similarity with no input ['necesserly']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['xen2', 'kryptosfr']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['ahahahahaha']
# WARNING:root:cannot compute similarity with no input ['ahah']
